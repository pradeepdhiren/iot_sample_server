# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\Dell\Downloads\customer_churn (5).csv')

# %%
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# ...

# %%
data_ = data.loc[:,['Churn','Contract','PaymentMethod']]

# %%
data_.head(5)
# Out:
#   Churn        Contract              PaymentMethod
# 0    No  Month-to-month           Electronic check
# 1    No        One year               Mailed check
# 2   Yes  Month-to-month               Mailed check
# 3    No        One year  Bank transfer (automatic)
# 4   Yes  Month-to-month           Electronic check

# %%
filter1 = data['Churn'].isin(['Yes'])

# %%
filter2 = data['PaymentMethod'].isin(['Mailed check'])

# %%
data = data_[filter1 & filter2]

# %%
data['Contract'].unique()
# Out:
# array(['Month-to-month', 'Two year', 'One year'], dtype=object)

# %%
filter1 = data['Contract'] == 'Two year'

# %%
data[filter1]
# Out:
#      Churn  Contract PaymentMethod
# 268    Yes  Two year  Mailed check
# 5947   Yes  Two year  Mailed check
# 6680   Yes  Two year  Mailed check

# %%
two_mail_yes = data[filter1]

# %%
data.head(333)
# Out:
#      Churn        Contract PaymentMethod
# 2      Yes  Month-to-month  Mailed check
# 22     Yes  Month-to-month  Mailed check
# 29     Yes  Month-to-month  Mailed check
# 97     Yes  Month-to-month  Mailed check
# 139    Yes  Month-to-month  Mailed check
# 151    Yes  Month-to-month  Mailed check
# 176    Yes  Month-to-month  Mailed check
# 223    Yes  Month-to-month  Mailed check
# 227    Yes  Month-to-month  Mailed check
# 232    Yes  Month-to-month  Mailed check
# 235    Yes  Month-to-month  Mailed check
# 248    Yes  Month-to-month  Mailed check
# 268    Yes        Two year  Mailed check
# 274    Yes  Month-to-month  Mailed check
# 284    Yes  Month-to-month  Mailed check
# 299    Yes  Month-to-month  Mailed check
# 334    Yes  Month-to-month  Mailed check
# 381    Yes  Month-to-month  Mailed check
# 385    Yes  Month-to-month  Mailed check
# 408    Yes  Month-to-month  Mailed check
# 409    Yes  Month-to-month  Mailed check
# 430    Yes  Month-to-month  Mailed check
# ...

# %%
customer_333 = data.head(333)

# %%
data['Churn'].unique()
# Out:
# array(['Yes'], dtype=object)
